# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('IPL_Dataset.csv')

# %%
data
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %% [markdown]
# # QUESTION 1
# # What is the maximum number of matches played by an individual player in a season?

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


max_matches_per_player = data.groupby('Player')['Mat'].max()


max_matches_player = max_matches_per_player.idxmax()
max_matches_count = max_matches_per_player.max()
print(max_matches_player)
print(max_matches_count)
print(f"The maximum number of matches played by an individual player in a season is {max_matches_count} by {max_matches_player}.")
# Out:
# Kagiso Rabada
# 17
# The maximum number of matches played by an individual player in a season is 17 by Kagiso Rabada.

# %% [markdown]
# # QUESTION 2
# # What is the highest average of a player in a season?

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


max_avg_per_player = data.groupby('Player')['Avg'].max()


max_avg_player = max_avg_per_player.idxmax()
max_avg_value = max_avg_per_player.max()

print(f"The highest batting average of an individual player in a season is {max_avg_value} by {max_avg_player}.")
# Out:
# The highest batting average of an individual player in a season is 101.0 by Deepak Hooda.

# %% [markdown]
# # QUESTION 3
# # What is the average number of matches played by the players in a season?

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


average_matches_per_player = data.groupby('Player')['Mat'].mean()


overall_average_matches = average_matches_per_player.mean()

print(f"The average number of matches played by players in a season is {overall_average_matches:.2f}.")
# Out:
# The average number of matches played by players in a season is 9.63.

# %% [markdown]
# # QUESTION 4
# # Please check the correlation between all the features.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


correlation_matrix = data.corr()


print(correlation_matrix)
# Out:
#            POS       Mat      Inns        NO      Runs       Avg        BF  \
# POS   1.000000 -0.556695 -0.916174 -0.386247 -0.896664 -0.746510 -0.891969
# Mat  -0.556695  1.000000  0.728358  0.555261  0.565237  0.306128  0.555102
# Inns -0.916174  0.728358  1.000000  0.464356  0.895914  0.585148  0.889753
# NO   -0.386247  0.555261  0.464356  1.000000  0.308747  0.429888  0.271021
# Runs -0.896664  0.565237  0.895914  0.308747  1.000000  0.687475  0.989948
# Avg  -0.746510  0.306128  0.585148  0.429888  0.687475  1.000000  0.664173
# BF   -0.891969  0.555102  0.889753  0.271021  0.989948  0.664173  1.000000
# SR   -0.730489  0.371328  0.581468  0.415060  0.517678  0.591306  0.474226
# 100  -0.248353  0.128405  0.224328  0.019726  0.382577  0.233726  0.358550
# 50   -0.769577  0.455437  0.755027  0.174184  0.912264  0.638326  0.900547
# 4s   -0.846965  0.522628  0.846749  0.204779  0.959576  0.623643  0.955994
# ...

# %% [markdown]
# # QUESTION 5
# # Check the list of players who has an average greater than 50 as well strike rate above 120.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


filtered_players = data[(data['Avg'] > 50) & (data['SR'] > 120)]


print("Players with an average greater than 50 and a strike rate above 120:")
print(filtered_players[['Player', 'Avg', 'SR']])
# Out:
# Players with an average greater than 50 and a strike rate above 120:
#              Player     Avg      SR
# 0          KL Rahul   55.83  129.34
# 4      Ishan Kishan   57.33  145.76
# 31   Kieron Pollard   53.60  191.42
# 36  Wriddhiman Saha   71.33  139.86
# 37  Ruturaj Gaikwad   51.00  120.71
# 57     Deepak Hooda  101.00  142.25
# 60       Tom Curran   83.00  133.87

# %% [markdown]
# # QUESTION 6
# # Please check the list of players who has an average greater than 40 and balls faced above 100.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


filtered_players = data[(data['Avg'] > 40) & (data['BF'] > 100)]


print("Players with an average greater than 40 and balls faced above 100:")
print(filtered_players[['Player', 'Avg', 'BF']])
# Out:
# Players with an average greater than 40 and balls faced above 100:
#              Player    Avg   BF
# 0          KL Rahul  55.83  518
# 1    Shikhar Dhawan  44.14  427
# 4      Ishan Kishan  57.33  354
# 8       Virat Kohli  42.36  384
# 9    AB de Villiers  45.40  286
# 10   Faf du Plessis  40.81  319
# 14      Eoin Morgan  41.80  302
# 24  Kane Williamson  45.28  237
# 27      Chris Gayle  41.14  210
# 28       Ben Stokes  40.71  200
# 31   Kieron Pollard  53.60  140
# 32    Rahul Tewatia  42.50  183
# 33  Ravindra Jadeja  46.40  135
# 36  Wriddhiman Saha  71.33  153
# 37  Ruturaj Gaikwad  51.00  169

# %% [markdown]
# # QUESTION 7
# # Please check the list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


filtered_players = data[(data['Runs'] > 300) & (data['Avg'] > 45) & (data['SR'] > 130)]


print("Players who scored more than 300 runs with an average greater than 45 and a strike rate above 130:")
print(filtered_players[['Player', 'Runs', 'Avg', 'SR']])
# Out:
# Players who scored more than 300 runs with an average greater than 45 and a strike rate above 130:
#              Player  Runs    Avg      SR
# 4      Ishan Kishan   516  57.33  145.76
# 9    AB de Villiers   454  45.40  158.74
# 24  Kane Williamson   317  45.28  133.75

# %% [markdown]
# # QUESTION 8
# # Players who scroed alteast one century in this season.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


century_scorers = data[data['100'] >= 1]


print("Players who scored at least one century in the season:")
print(century_scorers[['Player', '100']])
# Out:
# Players who scored at least one century in the season:
#             Player  100
# 0         KL Rahul    1
# 1   Shikhar Dhawan    2
# 13  Mayank Agarwal    1
# 28      Ben Stokes    1

# %% [markdown]
# # QUESTION 9
# # Players who scored atleast 4 half centuries in this season.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


four_half_century_scorers = data[data['50'] >= 4]


print("Players who scored at least four half-centuries in the season:")
print(four_half_century_scorers[['Player', '50']])
# Out:
# Players who scored at least four half-centuries in the season:
#               Player  50
# 0           KL Rahul   5
# 1     Shikhar Dhawan   4
# 2       David Warner   4
# 4       Ishan Kishan   4
# 5    Quinton de Kock   4
# 6   Suryakumar Yadav   4
# 7   Devdutt Padikkal   5
# 9     AB de Villiers   5
# 10    Faf du Plessis   4

# %% [markdown]
# # QUESTION 10
# # Check the list of players who hit more than 45 boundARIES and more than 10 sixes in this season.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


boundary_six_hitters = data[(data['4s'] > 45) & (data['6s'] > 10)]


print("Players who hit more than 45 boundaries and more than 10 sixes in the season:")
print(boundary_six_hitters[['Player', '4s', '6s']])
# Out:
# Players who hit more than 45 boundaries and more than 10 sixes in the season:
#              Player  4s  6s
# 0          KL Rahul  58  23
# 1    Shikhar Dhawan  67  12
# 2      David Warner  52  14
# 5   Quinton de Kock  46  22
# 6  Suryakumar Yadav  61  11

# %% [markdown]
# # QUESTION 11
# # Plot a histogram of number of matches played in a season by players.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('IPL_Dataset.csv')


plt.figure(figsize=(10, 6))
plt.hist(data['Mat'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Number of Matches Played by Players')
plt.xlabel('Number of Matches Played')
plt.ylabel('Number of Players')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %% [markdown]
# # QUESTION 12
# # Plot the histogram of balls faced by players.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('IPL_Dataset.csv')


plt.figure(figsize=(10, 6))
plt.hist(data['BF'], bins=20, color='orange', edgecolor='black')
plt.title('Histogram of Balls Faced by Players')
plt.xlabel('Number of Balls Faced')
plt.ylabel('Number of Players')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %% [markdown]
# # QUESTION 13
# # Top 20 players with most runs in a season.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


top_20_run_scorers = data.nlargest(20, 'Runs')


print("Top 20 players with the most runs in a season:")
print(top_20_run_scorers[['Player', 'Runs']])
# Out:
# Top 20 players with the most runs in a season:
#               Player  Runs
# 0           KL Rahul   670
# 1     Shikhar Dhawan   618
# 2       David Warner   548
# 3       Shreyas Iyer   519
# 4       Ishan Kishan   516
# 5    Quinton de Kock   503
# 6   Suryakumar Yadav   480
# 7   Devdutt Padikkal   473
# 8        Virat Kohli   466
# 9     AB de Villiers   454
# 10    Faf du Plessis   449
# 11      Shubman Gill   440
# 12     Manish Pandey   425
# 13    Mayank Agarwal   424
# 14       Eoin Morgan   418
# 15      Sanju Samson   375
# 16     Ambati Rayudu   359
# 17   Nicholas Pooran   353
# 18       Nitish Rana   352
# 19    Marcus Stoinis   352

# %% [markdown]
# # QUESTION 14
# # Bar chart for top 20 players with best strike rate in a season.

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('IPL_Dataset.csv')


top_20_strike_rate_players = data.nlargest(20, 'SR')


plt.figure(figsize=(12, 8))
plt.bar(top_20_strike_rate_players['Player'], top_20_strike_rate_players['SR'], color='green')
plt.title('Top 20 Players with the Best SR in a Season')
plt.xlabel('Player')
plt.ylabel('Strike Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# # QUESTION 15
# # Top 30 players with highest number of sixes.

# %%
import pandas as pd


data = pd.read_csv('IPL_Dataset.csv')


top_30_six_hitters = data.nlargest(30, '6s')


print("Top 30 players with the highest number of sixes in a season:")
print(top_30_six_hitters[['Player', '6s']])
# Out:
# Top 30 players with the highest number of sixes in a season:
#               Player  6s
# 4       Ishan Kishan  30
# 15      Sanju Samson  26
# 17   Nicholas Pooran  25
# 29     Hardik Pandya  25
# 14       Eoin Morgan  24
# 0           KL Rahul  23
# 9     AB de Villiers  23
# 27       Chris Gayle  23
# 5    Quinton de Kock  22
# 31    Kieron Pollard  22
# 22      Rohit Sharma  19
# 12     Manish Pandey  18
# 32     Rahul Tewatia  17
# 3       Shreyas Iyer  16
# 19    Marcus Stoinis  16
# 23       Jos Buttler  16
# 13    Mayank Agarwal  15
# 2       David Warner  14
# 10    Faf du Plessis  14
# 20    Jonny Bairstow  13
# 26      Shane Watson  13
# 1     Shikhar Dhawan  12
# 16     Ambati Rayudu  12
# 18       Nitish Rana  12
# 40        Sam Curran  12
# 41   Shimron Hetmyer  12
# 6   Suryakumar Yadav  11
# 8        Virat Kohli  11
# 33   Ravindra Jadeja  11
# 24   Kane Williamson  10

# %% [markdown]
# # QUESTION 16
# # Scatter plot of runs scored by a player v/s balls faced in a season.

# %% [markdown]
# # QUESTION 17
# # KDE plot for averages on a season.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv('IPL_Dataset.csv')


plt.figure(figsize=(10, 6))
sns.kdeplot(data['Avg'], fill=True, color='purple')
plt.title('Kernel Density Estimate (KDE) Plot for Averages in a Season')
plt.xlabel('Average')
plt.ylabel('Density')
plt.grid(True)
plt.show()
